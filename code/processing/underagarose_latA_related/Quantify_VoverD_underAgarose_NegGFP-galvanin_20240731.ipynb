# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import GridSpec
import matplotlib.gridspec as gridspec
import numpy as np
import glob
import pandas as pd
import math
import scipy as sp
from scipy.ndimage import gaussian_filter, binary_dilation
from skimage.measure import regionprops, label
import skimage
import skimage.io
from skimage.morphology import disk
from skimage.filters import rank

plt.style.use('styleNB.mplstyle')

import cv2
from aicsimageio import AICSImage
from aicsimageio.writers import OmeTiffWriter

# interpixel conversion
ip = 210.0/995.0 #995 pixels / 210 um interpixel distance

######################################
######################################
# Functions for segmentation
######################################
######################################

from scipy.ndimage import gaussian_filter, binary_closing, binary_opening

def generate_gradient_mask(image, threshold=50):
    """
    Generates a binary mask based on the gradient magnitude.

    Parameters:
        image (np.ndarray): The input 2D image.
        threshold (int): The threshold value for gradient magnitude.

    Returns:
        np.ndarray: The binary mask.
    """
    # Convert image to grayscale
    image = image.astype(np.float32)

    # Compute gradients using Sobel operator
    grad_x = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=3)
    grad_y = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=3)
    gradient_magnitude = np.sqrt(grad_x**2 + grad_y**2)

    # Threshold the gradient magnitude to generate the mask
    mask = (gradient_magnitude > threshold).astype(np.uint8)

    return mask


def smooth_mask_edges_morphological(mask, sigma=1.0, threshold=0.5, closing_iterations=1, opening_iterations=1):
    """
    Smooth the edges of a binary mask using Gaussian blurring followed by morphological closing and opening.
    
    Parameters:
    mask (np.ndarray): The input binary mask image.
    sigma (float): The standard deviation for Gaussian kernel. Higher values result in more smoothing.
    threshold (float): The threshold to convert the smoothed mask back to binary.
    closing_iterations (int): The number of iterations for the closing operation.
    opening_iterations (int): The number of iterations for the opening operation.
    
    Returns:
    np.ndarray: The smoothed binary mask image.
    """
    # Ensure the mask is binary (0 or 1)
    binary_mask = mask.astype(np.float32)
    
    # Apply Gaussian filter for smoothing
    smoothed_mask = gaussian_filter(binary_mask, sigma=sigma)
    
    # Normalize the smoothed mask to the range [0, 1]
    smoothed_mask = (smoothed_mask - smoothed_mask.min()) / (smoothed_mask.max() - smoothed_mask.min())
    
    # Apply threshold to convert back to binary mask
    smoothed_binary_mask = (smoothed_mask > threshold).astype(np.int32)
    
    # Apply morphological closing to smooth the edges
    closed_mask = binary_closing(smoothed_binary_mask, iterations=closing_iterations)
    
    # Apply morphological opening to further smooth the edges
    opened_mask = binary_opening(closed_mask, iterations=opening_iterations)
    
    return opened_mask.astype(np.int32)

######################################
######################################
# Functions for fitting
######################################
######################################

def model_func(t, A, K, C):
    return A * np.exp(K * t) + C    

def fit_exp_linear(t, y, C=0):
    y = y - C
    y = np.log(y)
    K, A_log = np.polyfit(t, y, 1)
    A = np.exp(A_log)
    return A, K

# %% [markdown]
# # 2024071*_LatA_GalvGFP

# %%
def analysis_identifyCells(f, threshold):
    df_cells = pd.DataFrame()

    im_mask_ = np.empty((151, 1024, 1024))

    ######################
    # Segmentation
    ######################

    # load image 
    img = AICSImage(f)  
    im = img.get_image_data("TCZYX") 
    im_ph = im[:,0,0,:,:] # select phase image
    im_gfp = im[:,1,0,:,:] 

    # perform segmentation
    for i in np.arange(im_ph.shape[0]): #[:1]:
        # gradient of phase image, with threshold cutoff to identify cell boundaries 
        im_temp = generate_gradient_mask(im_ph[i,:,:], threshold=threshold)#600)

        # dilate to connect any discontinuities and fill holes
        bw = sp.ndimage.binary_dilation(im_temp, structure = np.ones((1,1)), iterations=1)
        bw = sp.ndimage.binary_fill_holes(bw)

        # erode a bit to shrink masks
        bw_mask = sp.ndimage.binary_erosion(bw, structure = np.ones((3,3)), iterations=2)

        # smooth_mask_edges
        im_mask_[i,:,:] = smooth_mask_edges_morphological(bw_mask, 
                                                         sigma=3.0, 
                                                         threshold=0.5, 
                                                         closing_iterations=2, 
                                                         opening_iterations=2)


    ######################
    # Identify cells to quantify
    ######################

    im_labeled, n_labels = skimage.measure.label(im_mask_[0,:,:], background=0, return_num=True)
    im_props = skimage.measure.regionprops(im_labeled)

    for L, prop in enumerate(im_props):

        # identify only the cells that have decent fluorescence
        im_labeled_temp = im_labeled.copy()
        im_labeled_temp[im_labeled_temp!=L+1] = 0

        # Only select objects that are big enough to be a cell and are fluorescent
        if np.all([prop.area >= 1000, np.mean(np.multiply(im_labeled_temp, im_gfp[0,:,:])) >=0.5]):

            datalist = {'cell' : L+1,
                        'centroid' : prop.centroid, 
                        'current' : f.split('mA')[0][-3:]+'mA',
                        'electric field' : dict_files_E[f],
                        'trial' : f.split('mA')[1][1],
                       'file' : f}

            df_cells = pd.concat([df_cells, pd.DataFrame([datalist])], ignore_index=True)
            
    return df_cells, im_mask_, im_gfp



def analysis_fcn(im_gfp, im_mask_, df_cells, leftbound, rightbound, 
                 upperbound, lowerbound, cell, cellular_auto, frames):          

    for g, d in df_cells.groupby(['current', 'trial']):
        print(g)
        # grab correct mask 
        im_mask = im_mask_#[mask_ind, :, :, :]


        for cell_val in d.cell.unique():
            if cell_val != cell:
                continue
            print(cell_val)
 
            for count, i in enumerate(frames):
                #######
                # 1. Identify cell in mask 
                #######

                im_labeled_0, _ = skimage.measure.label(im_mask[0,:,:], background=0, return_num=True)
                centroid_y = np.floor(d[d.cell == cell_val].centroid.values[0]).astype('int')[0]
                centroid_x = np.floor(d[d.cell == cell_val].centroid.values[0]).astype('int')[1]
                ind = im_labeled_0[centroid_y, centroid_x]
                im_labeled_0[im_labeled_0 != ind] = 0

                im_labeled, _ = skimage.measure.label(im_mask[i,:,:], background=0, return_num=True)

                if len(np.unique(np.multiply(im_labeled_0, im_labeled))) < 2:
                    continue

                ind_update = np.unique(np.multiply(im_labeled_0, im_labeled))[1]/ind

                im_labeled[im_labeled != ind_update] = 0
                im_labeled[im_labeled>0] = 1

                im_m = im_labeled

                #######
                # 2. Crop region of interest with some padding around cell (for both intensity image and mask)
                #######
                rows, cols = np.where(im_labeled == 1)
                pad = 0
                min_row, max_row = np.max([0,np.min(rows)-pad]), np.min([1024, np.max(rows)+pad])
                min_col, max_col = np.max([0,np.min(cols)-pad]), np.min([1024, np.max(cols)+pad])

                im_temp = im_gfp[i,min_row:max_row,min_col:max_col]
                
                vals = np.mean(im_temp[int(im_temp.shape[0]/2)+upperbound:int(im_temp.shape[0]/2)+lowerbound,:], axis = 0)

                #######
                # 3. Quantify  intensity
                #######
                # Convert to real micron units 
                # Since I split the edge into 300 posiitons, 
                # need to convert to pixels and then to micron.
                x = np.arange(len(vals))/(995/210)

                vals_zeroed = vals - cellular_auto
                vals_renorm = vals_zeroed 
                
                #######
                # 4. Take a look at values
                #######

                # Create a figure
                fig = plt.figure(figsize=(8, 4), tight_layout=True)

                # Define a GridSpec with the desired width ratios
                gs = GridSpec(1, 3, width_ratios=[2, 1, 1], figure=fig)

                # Create subplots
                ax1 = fig.add_subplot(gs[0])
                ax2 = fig.add_subplot(gs[1])
                ax3 = fig.add_subplot(gs[2])


                ax1.plot(x, vals_renorm, 'ro',alpha = 0.4)
                ax1.set_ylabel('fluorescence\nintensity (a.u.)')
                ax1.set_xlabel(r'position along cell edge ($\mu$m)')

                ax2.imshow(im_temp)

                ax3.imshow(im_temp[int(im_temp.shape[0]/2)+upperbound:int(im_temp.shape[0]/2)+lowerbound,:])
                ax3.set_title(str(cell_val))

                # region of interest (avoid edges)
                x_ = x[leftbound:rightbound]
                vals_renorm_ =  vals_renorm[leftbound:rightbound]

                # for fitting
                x__= x_
                y__ = vals_renorm_

                ax1.plot(x, vals_renorm , 'ro',alpha = 0.4)
                ax1.plot(x_, vals_renorm_ , 'bo',alpha = 0.4)

                A = 1
                K1 = -0.1
                A, K1 = fit_exp_linear(x__, y__)

                fit_y = model_func(x__, A, K1, 0)

                ax1.plot(x__, fit_y, linewidth = 4.0, color = 'g')
                
                ax1.set_yscale('log')
                print('v/D ~ '+str(np.round(np.abs(K1),3))+r' $\mu$m$^{-1}$')
                
                
                ax1.set_ylim(1, np.max(vals_renorm)+40)
                ax1.set_yscale('log')

# %%
# autofluorescence value - estimated based on pixel values (EF on, 
# 500 mV/mm) in imageJ
cellular_auto = 170

# %% [markdown]
# # 5 V/cm electric field condition data
#
# Note that due to the much poorer fluorescence signal, only the highest electric field condition was consider for quantification (i.e. where we could get a clean enough biased fluorescence signal)

# %%
files = glob.glob('../../../data/microscopy/Amy/202407*_LatA/202407*2.2mA*/*LatA_*-30*.tif')
files

files_E = [5, 5, 5]

dict_files_E = dict(zip(files, files_E))
dict_files_E
# Out:
# {'../../../data/microscopy/Amy/20240711_LatA/20240711_LatA_-30GFP_Galv_2.2mA_2/20240711_LatA_-30GFP_Galv_2.2mA_2_MMStack_Pos0.ome.tif': 5,
#  '../../../data/microscopy/Amy/20240711_LatA/20240711_LatA_-30GFP_Galv_2.2mA_4/20240711_LatA_-30GFP_Galv_2.2mA_4_MMStack_Pos0.ome.tif': 5,
#  '../../../data/microscopy/Amy/20240711_LatA/20240711_LatA_-30GFP_Galv_2.2mA_3/20240711_LatA_-30GFP_Galv_2.2mA_3_MMStack_Pos0.ome.tif': 5}

# %% [markdown]
# ## '../../data/microscopy/Amy/20240711_LatA/20240711_LatA_-30GFP_Galv_2.2mA_2/20240711_LatA_-30GFP_Galv_2.2mA_2_MMStack_Pos0.ome.tif'

# %%
f = files[0]
threshold = 600

df_cells, im_mask_, im_gfp = analysis_identifyCells(f, threshold)
df_cells
# Out:
# <tifffile.TiffFile '20240711_LatA_-3…ck_Pos0.ome.tif'> OME series failed to read '20240711_LatA_-30GFP_Galv_1.2mA_5_MMStack_Pos0.ome.tif'. Missing data are zeroed
# <tifffile.TiffFile '20240711_LatA_-3…ck_Pos0.ome.tif'> OME series failed to read 302 files
# <tifffile.TiffFile '20240711_LatA_-3…ck_Pos0.ome.tif'> OME series failed to read '20240711_LatA_-30GFP_Galv_1.2mA_5_MMStack_Pos0.ome.tif'. Missing data are zeroed
# <tifffile.TiffFile '20240711_LatA_-3…ck_Pos0.ome.tif'> OME series failed to read 302 files
#     cell                                  centroid current  electric field  \
# 0      1   (90.85546486163648, 367.41688234123035)   2.2mA               5
# 1      2    (42.78880643166357, 679.3116883116883)   2.2mA               5
# 2      5   (179.95638432364095, 757.6652970922883)   2.2mA               5
# 3      6  (205.13048965169108, 128.54492680464412)   2.2mA               5
# 4      7   (243.51745635910225, 62.68536990856193)   2.2mA               5
# 5      9   (348.69495548961424, 754.1673590504452)   2.2mA               5
# 6     11     (353.3844696969697, 881.110321969697)   2.2mA               5
# 7     13   (459.35893155258765, 986.1455759599332)   2.2mA               5
# 8     14   (473.50995024875624, 439.1507462686567)   2.2mA               5
# 9     16     (535.1804482225657, 89.3404173106646)   2.2mA               5
# 10    18    (603.2091097308488, 729.8028985507246)   2.2mA               5
# 11    22    (745.2515673981192, 645.6873040752351)   2.2mA               5
# 12    24    (896.5702373316228, 50.01828094932649)   2.2mA               5
# 13    25     (918.0453345070423, 270.306338028169)   2.2mA               5
# 14    26    (939.2042665659808, 687.4674343968284)   2.2mA               5
# 15    27    (949.2245289045034, 486.8265729798786)   2.2mA               5
#
#    trial                                               file
# 0      2  ../../data/microscopy/Amy/20240711_LatA/202407...
# 1      2  ../../data/microscopy/Amy/20240711_LatA/202407...
# 2      2  ../../data/microscopy/Amy/20240711_LatA/202407...
# 3      2  ../../data/microscopy/Amy/20240711_LatA/202407...
# 4      2  ../../data/microscopy/Amy/20240711_LatA/202407...
# 5      2  ../../data/microscopy/Amy/20240711_LatA/202407...
# 6      2  ../../data/microscopy/Amy/20240711_LatA/202407...
# 7      2  ../../data/microscopy/Amy/20240711_LatA/202407...
# 8      2  ../../data/microscopy/Amy/20240711_LatA/202407...
# 9      2  ../../data/microscopy/Amy/20240711_LatA/202407...
# 10     2  ../../data/microscopy/Amy/20240711_LatA/202407...
# 11     2  ../../data/microscopy/Amy/20240711_LatA/202407...
# 12     2  ../../data/microscopy/Amy/20240711_LatA/202407...
# 13     2  ../../data/microscopy/Amy/20240711_LatA/202407...
# 14     2  ../../data/microscopy/Amy/20240711_LatA/202407...
# 15     2  ../../data/microscopy/Amy/20240711_LatA/202407...

# %%
df_cells.cell.unique()
# Out:
# array([ 1,  2,  5,  6,  7,  9, 11, 13, 14, 16, 18, 22, 24, 25, 26, 27])

# %%
cell = 5

# region e.g. [20:-20]
leftbound = 10
rightbound = -50

# region e.g. [centroid_y -10: centroid_y + 10]
upperbound = -10
lowerbound = 10

frames = np.arange(89,90)

analysis_fcn(im_gfp, im_mask_, df_cells, leftbound, 
             rightbound, upperbound, lowerbound,
             cell, cellular_auto, frames)
# Out:
# ('2.2mA', '2')
# 5
# v/D ~ 0.303 $\mu$m$^{-1}$

# %%
# [ 1,  2,  5,  6,  7,  9, 11, 13, 14, 16, 18, 22, 24, 25, 26, 27]
cell = 6

# region e.g. [20:-20]
leftbound = 10
rightbound = -35


# region e.g. [centroid_y -10: centroid_y + 10]
upperbound = -10
lowerbound = 10

frames = np.arange(88,89)

analysis_fcn(im_gfp, im_mask_, df_cells, leftbound, 
             rightbound, upperbound, lowerbound,
             cell, cellular_auto, frames)
# Out:
# ('2.2mA', '2')
# 6
# v/D ~ 0.185 $\mu$m$^{-1}$

# %%
# [ 1,  2,  5,  6,  7,  9, 11, 13, 14, 16, 18, 22, 24, 25, 26, 27]
cell = 7

# region e.g. [20:-20]
leftbound = 5
rightbound = -25

# region e.g. [centroid_y -10: centroid_y + 10]
upperbound = -10
lowerbound = 0

frames = np.arange(88,89)

analysis_fcn(im_gfp, im_mask_, df_cells, leftbound, 
             rightbound, upperbound, lowerbound,
             cell, cellular_auto, frames)
# Out:
# ('2.2mA', '2')
# 7
# v/D ~ 0.25 $\mu$m$^{-1}$

# %%
# [ 1,  2,  5,  6,  7,  9, 11, 13, 14, 16, 18, 22, 24, 25, 26, 27]
cell = 9

# region e.g. [20:-20]
leftbound = 10
rightbound = -10

# region e.g. [centroid_y -10: centroid_y + 10]
upperbound = -10
lowerbound = 0

frames = np.arange(85,86)

analysis_fcn(im_gfp, im_mask_, df_cells, leftbound, 
             rightbound, upperbound, lowerbound,
             cell, cellular_auto, frames)
# Out:
# ('2.2mA', '2')
# 9
# v/D ~ 0.384 $\mu$m$^{-1}$

# %%
# [ 1,  2,  5,  6,  7,  9, 11, 13, 14, 16, 18, 22, 24, 25, 26, 27]
cell = 11

# region e.g. [20:-20]
leftbound = 10
rightbound = -20#-10

# region e.g. [centroid_y -10: centroid_y + 10]
upperbound = -10
lowerbound = 0

frames = np.arange(85,86)

analysis_fcn(im_gfp, im_mask_, df_cells, leftbound, 
             rightbound, upperbound, lowerbound,
             cell, cellular_auto, frames)
# Out:
# ('2.2mA', '2')
# 11
# v/D ~ 0.189 $\mu$m$^{-1}$

# %%
# [ 1,  2,  5,  6,  7,  9, 11, 13, 14, 16, 18, 22, 24, 25, 26, 27]
cell = 13

# region e.g. [20:-20]
leftbound = 10
rightbound = -40#-10

# region e.g. [centroid_y -10: centroid_y + 10]
upperbound = -5
lowerbound = 10

frames = np.arange(85,86)

analysis_fcn(im_gfp, im_mask_, df_cells, leftbound, 
             rightbound, upperbound, lowerbound,
             cell, cellular_auto-5, frames)
# Out:
# ('2.2mA', '2')
# 13
# v/D ~ 0.379 $\mu$m$^{-1}$

# %%
# [ 1,  2,  5,  6,  7,  9, 11, 13, 14, 16, 18, 22, 24, 25, 26, 27]
cell = 14

# region e.g. [20:-20]
leftbound = 10
rightbound = -20

# region e.g. [centroid_y -10: centroid_y + 10]
upperbound = -10
lowerbound = 0

frames = np.arange(85,86)

analysis_fcn(im_gfp, im_mask_, df_cells, leftbound, 
             rightbound, upperbound, lowerbound,
             cell, cellular_auto, frames)
# Out:
# ('2.2mA', '2')
# 14
# v/D ~ 0.26 $\mu$m$^{-1}$

# %%
# [ 1,  2,  5,  6,  7,  9, 11, 13, 14, 16, 18, 22, 24, 25, 26, 27]
cell = 18

# region e.g. [20:-20]
leftbound = 20
rightbound = -30

# region e.g. [centroid_y -10: centroid_y + 10]
upperbound = -10
lowerbound = 0

frames = np.arange(85,86)

analysis_fcn(im_gfp, im_mask_, df_cells, leftbound, 
             rightbound, upperbound, lowerbound,
             cell, cellular_auto, frames)
# Out:
# ('2.2mA', '2')
# 18
# v/D ~ 0.366 $\mu$m$^{-1}$

# %%
# [ 1,  2,  5,  6,  7,  9, 11, 13, 14, 16, 18, 22, 24, 25, 26, 27]
cell = 22

# region e.g. [20:-20]
leftbound = 15
rightbound = -15

# region e.g. [centroid_y -10: centroid_y + 10]
upperbound = -10
lowerbound = 0

frames = np.arange(85,86)

analysis_fcn(im_gfp, im_mask_, df_cells, leftbound, 
             rightbound, upperbound, lowerbound,
             cell, cellular_auto, frames)
# Out:
# ('2.2mA', '2')
# 22
# v/D ~ 0.224 $\mu$m$^{-1}$

# %%
# [ 1,  2,  5,  6,  7,  9, 11, 13, 14, 16, 18, 22, 24, 25, 26, 27]
cell = 24

# region e.g. [20:-20]
leftbound = 10
rightbound = -25#-10

# region e.g. [centroid_y -10: centroid_y + 10]
upperbound = -10
lowerbound = 0

frames = np.arange(85,86)

analysis_fcn(im_gfp, im_mask_, df_cells, leftbound, 
             rightbound, upperbound, lowerbound,
             cell, cellular_auto, frames)
# Out:
# ('2.2mA', '2')
# 24
# v/D ~ 0.206 $\mu$m$^{-1}$

# %%
# [ 1,  2,  5,  6,  7,  9, 11, 13, 14, 16, 18, 22, 24, 25, 26, 27]
cell = 25

# region e.g. [20:-20]
leftbound = 10
rightbound = -15

# region e.g. [centroid_y -10: centroid_y + 10]
upperbound = -10
lowerbound = 0

frames = np.arange(85,86)

analysis_fcn(im_gfp, im_mask_, df_cells, leftbound, 
             rightbound, upperbound, lowerbound,
             cell, cellular_auto, frames)
# Out:
# ('2.2mA', '2')
# 25
# v/D ~ 0.265 $\mu$m$^{-1}$

# %%
# [ 1,  2,  5,  6,  7,  9, 11, 13, 14, 16, 18, 22, 24, 25, 26, 27]
cell = 26

# region e.g. [20:-20]
leftbound = 70
rightbound = -60#-40

# region e.g. [centroid_y -10: centroid_y + 10]
upperbound = -10
lowerbound = 0

frames = np.arange(85,86)

analysis_fcn(im_gfp, im_mask_, df_cells, leftbound, 
             rightbound, upperbound, lowerbound,
             cell, cellular_auto, frames)
# Out:
# ('2.2mA', '2')
# 26
# v/D ~ 0.19 $\mu$m$^{-1}$

# %% [markdown]
# ## '../../data/microscopy/Amy/20240711_LatA/20240711_LatA_-30GFP_Galv_2.2mA_4/20240711_LatA_-30GFP_Galv_2.2mA_4_MMStack_Pos0.ome.tif'

# %%
f = files[1]
threshold = 600

df_cells, im_mask_, im_gfp = analysis_identifyCells(f, threshold)
df_cells
# Out:
#     cell                                  centroid current  electric field  \
# 0      3   (154.54872624342903, 760.5046502224019)   2.2mA               5
# 1      8   (282.70802216333414, 97.29029149602505)   2.2mA               5
# 2      9  (293.54917025199757, 359.00829748002457)   2.2mA               5
# 3     14  (457.04372496662216, 134.90821094793057)   2.2mA               5
# 4     17   (500.3405842137974, 504.54008701056557)   2.2mA               5
# 5     18     (591.775567516967, 752.2246665106483)   2.2mA               5
# 6     19    (631.6803753795198, 315.4659122274358)   2.2mA               5
# 7     21   (835.1826725403818, 392.12569750367106)   2.2mA               5
# 8     22    (889.4439528023598, 564.7244837758112)   2.2mA               5
# 9     23      (905.0460914454277, 847.38901179941)   2.2mA               5
# 10    24   (999.4078152753108, 405.34422735346357)   2.2mA               5
#
#    trial                                               file
# 0      4  ../../data/microscopy/Amy/20240711_LatA/202407...
# 1      4  ../../data/microscopy/Amy/20240711_LatA/202407...
# 2      4  ../../data/microscopy/Amy/20240711_LatA/202407...
# 3      4  ../../data/microscopy/Amy/20240711_LatA/202407...
# 4      4  ../../data/microscopy/Amy/20240711_LatA/202407...
# 5      4  ../../data/microscopy/Amy/20240711_LatA/202407...
# 6      4  ../../data/microscopy/Amy/20240711_LatA/202407...
# 7      4  ../../data/microscopy/Amy/20240711_LatA/202407...
# 8      4  ../../data/microscopy/Amy/20240711_LatA/202407...
# 9      4  ../../data/microscopy/Amy/20240711_LatA/202407...
# 10     4  ../../data/microscopy/Amy/20240711_LatA/202407...

# %%
df_cells.cell.unique()
# Out:
# array([ 3,  8,  9, 14, 17, 18, 19, 21, 22, 23, 24])

# %%
# [ 3,  8,  9, 14, 17, 18, 19, 21, 22, 23, 24]
cell = 3

# region e.g. [20:-20]
leftbound = 15
rightbound = -28

# region e.g. [centroid_y -10: centroid_y + 10]
upperbound = 0
lowerbound = 10

frames = np.arange(89,90)

analysis_fcn(im_gfp, im_mask_, df_cells, leftbound, 
             rightbound, upperbound, lowerbound,
             cell, cellular_auto, frames)
# Out:
# ('2.2mA', '4')
# 3
# v/D ~ 0.347 $\mu$m$^{-1}$

# %%
# [ 3,  8,  9, 14, 17, 18, 19, 21, 22, 23, 24]
cell = 9

# region e.g. [20:-20]
leftbound = 10
rightbound = -15

# region e.g. [centroid_y -10: centroid_y + 10]
upperbound = -10
lowerbound = 10

frames = np.arange(89,90)

analysis_fcn(im_gfp, im_mask_, df_cells, leftbound, 
             rightbound, upperbound, lowerbound,
             cell, cellular_auto, frames)
# Out:
# ('2.2mA', '4')
# 9
# v/D ~ 0.133 $\mu$m$^{-1}$

# %%
# [ 3,  8,  9, 14, 17, 18, 19, 21, 22, 23, 24]
cell = 14

# region e.g. [20:-20]
leftbound = 10
rightbound = -10

# region e.g. [centroid_y -10: centroid_y + 10]
upperbound = -5
lowerbound = 5

frames = np.arange(89,90)

analysis_fcn(im_gfp, im_mask_, df_cells, leftbound, 
             rightbound, upperbound, lowerbound,
             cell, cellular_auto, frames)
# Out:
# ('2.2mA', '4')
# 14
# v/D ~ 0.245 $\mu$m$^{-1}$

# %%
# [ 3,  8,  9, 14, 17, 18, 19, 21, 22, 23, 24]
cell = 17

# region e.g. [20:-20]
leftbound = 15
rightbound = -15

# region e.g. [centroid_y -10: centroid_y + 10]
upperbound = -10
lowerbound = 10

frames = np.arange(89,90)

analysis_fcn(im_gfp, im_mask_, df_cells, leftbound, 
             rightbound, upperbound, lowerbound,
             cell, cellular_auto, frames)
# Out:
# ('2.2mA', '4')
# 17
# v/D ~ 0.197 $\mu$m$^{-1}$

# %%
# [ 3,  8,  9, 14, 17, 18, 19, 21, 22, 23, 24]
cell = 18

# region e.g. [20:-20]
leftbound = 15
rightbound = -40

# region e.g. [centroid_y -10: centroid_y + 10]
upperbound = -10
lowerbound = 10

frames = np.arange(89,90)

analysis_fcn(im_gfp, im_mask_, df_cells, leftbound, 
             rightbound, upperbound, lowerbound,
             cell, cellular_auto, frames)
# Out:
# ('2.2mA', '4')
# 18
# v/D ~ 0.259 $\mu$m$^{-1}$

# %%
# [ 3,  8,  9, 14, 17, 18, 19, 21, 22, 23, 24]
cell = 21

# region e.g. [20:-20]
leftbound = 15
rightbound = -20

# region e.g. [centroid_y -10: centroid_y + 10]
upperbound = -10
lowerbound = 10

frames = np.arange(89,90)

analysis_fcn(im_gfp, im_mask_, df_cells, leftbound, 
             rightbound, upperbound, lowerbound,
             cell, cellular_auto, frames)
# Out:
# ('2.2mA', '4')
# 21
# v/D ~ 0.23 $\mu$m$^{-1}$

# %%
# [ 3,  8,  9, 14, 17, 18, 19, 21, 22, 23, 24]
cell = 22

# region e.g. [20:-20]
leftbound = 15
rightbound = -20

# region e.g. [centroid_y -10: centroid_y + 10]
upperbound = -10
lowerbound = 10

frames = np.arange(89,90)

analysis_fcn(im_gfp, im_mask_, df_cells, leftbound, 
             rightbound, upperbound, lowerbound,
             cell, cellular_auto, frames)
# Out:
# ('2.2mA', '4')
# 22
# v/D ~ 0.142 $\mu$m$^{-1}$

# %%
# [ 3,  8,  9, 14, 17, 18, 19, 21, 22, 23, 24]
cell = 23

# region e.g. [20:-20]
leftbound = 20
rightbound = -40

# region e.g. [centroid_y -10: centroid_y + 10]
upperbound = -10
lowerbound = 10

frames = np.arange(89,90)

analysis_fcn(im_gfp, im_mask_, df_cells, leftbound, 
             rightbound, upperbound, lowerbound,
             cell, cellular_auto, frames)
# Out:
# ('2.2mA', '4')
# 23
# v/D ~ 0.184 $\mu$m$^{-1}$

# %% [markdown]
# ## '../../data/microscopy/Amy/20240711_LatA/20240711_LatA_-30GFP_Galv_2.2mA_3/20240711_LatA_-30GFP_Galv_2.2mA_3_MMStack_Pos0.ome.tif'

# %%
f = files[2]
threshold = 600

df_cells, im_mask_, im_gfp = analysis_identifyCells(f, threshold)
df_cells
# Out:
# <tifffile.TiffFile '20240711_LatA_-3…ck_Pos0.ome.tif'> OME series failed to read '20240711_LatA_-30GFP_Galv_1.2mA_5_MMStack_Pos0.ome.tif'. Missing data are zeroed
# <tifffile.TiffFile '20240711_LatA_-3…ck_Pos0.ome.tif'> OME series failed to read 302 files
# <tifffile.TiffFile '20240711_LatA_-3…ck_Pos0.ome.tif'> OME series failed to read '20240711_LatA_-30GFP_Galv_1.2mA_5_MMStack_Pos0.ome.tif'. Missing data are zeroed
# <tifffile.TiffFile '20240711_LatA_-3…ck_Pos0.ome.tif'> OME series failed to read 302 files
#     cell                                  centroid current  electric field  \
# 0      1   (50.975506926320016, 864.6370206785786)   2.2mA               5
# 1      2    (99.95371621621622, 745.4506756756757)   2.2mA               5
# 2      4   (159.83829973707273, 978.2475898334794)   2.2mA               5
# 3      5   (178.77257525083613, 769.6655518394649)   2.2mA               5
# 4      7  (306.22282189668465, 196.41511179645335)   2.2mA               5
# 5      8   (305.46463450725065, 72.51968037881029)   2.2mA               5
# 6      9    (337.7790019442644, 804.3344134802334)   2.2mA               5
# 7     11   (359.06832917705736, 317.5366583541147)   2.2mA               5
# 8     13   (511.52827305145183, 774.1395822720326)   2.2mA               5
# 9     17   (681.2622077537733, 364.07517016868894)   2.2mA               5
# 10    18   (693.1399626766196, 28.486803519061585)   2.2mA               5
# 11    19    (681.6072169224389, 602.1281625881377)   2.2mA               5
# 12    22   (826.7015407554672, 139.08971172962228)   2.2mA               5
# 13    23    (951.5405240706885, 709.5859232175503)   2.2mA               5
# 14    24    (974.1246835443038, 551.7168776371308)   2.2mA               5
# 15    25    (981.4228349370836, 887.3908216136196)   2.2mA               5
#
#    trial                                               file
# 0      3  ../../data/microscopy/Amy/20240711_LatA/202407...
# 1      3  ../../data/microscopy/Amy/20240711_LatA/202407...
# 2      3  ../../data/microscopy/Amy/20240711_LatA/202407...
# 3      3  ../../data/microscopy/Amy/20240711_LatA/202407...
# 4      3  ../../data/microscopy/Amy/20240711_LatA/202407...
# 5      3  ../../data/microscopy/Amy/20240711_LatA/202407...
# 6      3  ../../data/microscopy/Amy/20240711_LatA/202407...
# 7      3  ../../data/microscopy/Amy/20240711_LatA/202407...
# 8      3  ../../data/microscopy/Amy/20240711_LatA/202407...
# 9      3  ../../data/microscopy/Amy/20240711_LatA/202407...
# 10     3  ../../data/microscopy/Amy/20240711_LatA/202407...
# 11     3  ../../data/microscopy/Amy/20240711_LatA/202407...
# 12     3  ../../data/microscopy/Amy/20240711_LatA/202407...
# 13     3  ../../data/microscopy/Amy/20240711_LatA/202407...
# 14     3  ../../data/microscopy/Amy/20240711_LatA/202407...
# 15     3  ../../data/microscopy/Amy/20240711_LatA/202407...

# %%
df_cells.cell.unique()
# Out:
# array([ 1,  2,  4,  5,  7,  8,  9, 11, 13, 17, 18, 19, 22, 23, 24, 25])

# %%
# [ 1,  2,  4,  5,  7,  8,  9, 11, 13, 17, 18, 19, 22, 23, 24, 25]
cell = 5

# region e.g. [20:-20]
leftbound = 10
rightbound = -30

# region e.g. [centroid_y -10: centroid_y + 10]
upperbound = -10
lowerbound = 10

frames = np.arange(89,90)

analysis_fcn(im_gfp, im_mask_, df_cells, leftbound, 
             rightbound, upperbound, lowerbound,
             cell, cellular_auto, frames)
# Out:
# ('2.2mA', '3')
# 5
# v/D ~ 0.398 $\mu$m$^{-1}$

# %%
# [ 1,  2,  4,  5,  7,  8,  9, 11, 13, 17, 18, 19, 22, 23, 24, 25]
cell = 9

# region e.g. [20:-20]
leftbound = 20
rightbound = -30

# region e.g. [centroid_y -10: centroid_y + 10]
upperbound = -5
lowerbound = 5

frames = np.arange(89,90)

analysis_fcn(im_gfp, im_mask_, df_cells, leftbound, 
             rightbound, upperbound, lowerbound,
             cell, cellular_auto, frames)
# Out:
# ('2.2mA', '3')
# 9
# v/D ~ 0.414 $\mu$m$^{-1}$

# %%
# [ 1,  2,  4,  5,  7,  8,  9, 11, 13, 17, 18, 19, 22, 23, 24, 25]
cell = 11

# region e.g. [20:-20]
leftbound = 10
rightbound = -20

# region e.g. [centroid_y -10: centroid_y + 10]
upperbound = -5
lowerbound = 5

frames = np.arange(89,90)

analysis_fcn(im_gfp, im_mask_, df_cells, leftbound, 
             rightbound, upperbound, lowerbound,
             cell, cellular_auto, frames)
# Out:
# ('2.2mA', '3')
# 11
# v/D ~ 0.415 $\mu$m$^{-1}$

# %%
# [ 1,  2,  4,  5,  7,  8,  9, 11, 13, 17, 18, 19, 22, 23, 24, 25]
cell = 13

# region e.g. [20:-20]
leftbound = 15
rightbound = -25

# region e.g. [centroid_y -10: centroid_y + 10]
upperbound = -5
lowerbound = 5

frames = np.arange(89,90)

analysis_fcn(im_gfp, im_mask_, df_cells, leftbound, 
             rightbound, upperbound, lowerbound,
             cell, cellular_auto, frames)
# Out:
# ('2.2mA', '3')
# 13
# v/D ~ 0.355 $\mu$m$^{-1}$

# %%
# [ 1,  2,  4,  5,  7,  8,  9, 11, 13, 17, 18, 19, 22, 23, 24, 25]
cell = 17

# region e.g. [20:-20]
leftbound = 10
rightbound = -25

# region e.g. [centroid_y -10: centroid_y + 10]
upperbound = -5
lowerbound = 5

frames = np.arange(89,90)

analysis_fcn(im_gfp, im_mask_, df_cells, leftbound, 
             rightbound, upperbound, lowerbound,
             cell, cellular_auto, frames)
# Out:
# ('2.2mA', '3')
# 17
# v/D ~ 0.152 $\mu$m$^{-1}$

# %%
# [ 1,  2,  4,  5,  7,  8,  9, 11, 13, 17, 18, 19, 22, 23, 24, 25]
cell = 19

# region e.g. [20:-20]
leftbound = 10
rightbound = -20

# region e.g. [centroid_y -10: centroid_y + 10]
upperbound = -5
lowerbound = 5

frames = np.arange(89,90)

analysis_fcn(im_gfp, im_mask_, df_cells, leftbound, 
             rightbound, upperbound, lowerbound,
             cell, cellular_auto, frames)
# Out:
# ('2.2mA', '3')
# 19
# v/D ~ 0.144 $\mu$m$^{-1}$

# %%
# [ 1,  2,  4,  5,  7,  8,  9, 11, 13, 17, 18, 19, 22, 23, 24, 25]
cell = 22

# region e.g. [20:-20]
leftbound = 10
rightbound = -30

# region e.g. [centroid_y -10: centroid_y + 10]
upperbound = -5
lowerbound = 5

frames = np.arange(89,90)

analysis_fcn(im_gfp, im_mask_, df_cells, leftbound, 
             rightbound, upperbound, lowerbound,
             cell, cellular_auto, frames)
# Out:
# ('2.2mA', '3')
# 22
# v/D ~ 0.245 $\mu$m$^{-1}$

# %%
# [ 1,  2,  4,  5,  7,  8,  9, 11, 13, 17, 18, 19, 22, 23, 24, 25]
cell = 23

# region e.g. [20:-20]
leftbound = 10
rightbound = -40

# region e.g. [centroid_y -10: centroid_y + 10]
upperbound = -5
lowerbound = 5

frames = np.arange(89,90)

analysis_fcn(im_gfp, im_mask_, df_cells, leftbound, 
             rightbound, upperbound, lowerbound,
             cell, cellular_auto, frames)
# Out:
# ('2.2mA', '3')
# 23
# v/D ~ 0.137 $\mu$m$^{-1}$

# %% [markdown]
# # Summary

# %%
vD_5 = np.array([0.303, 0.185, 0.25, 0.384, 0.189, 0.379, 0.26, 0.366, 0.224, 0.206, 0.265, 0.19, 0.347, 0.133,
            0.245, 0.197, 0.259, 0.23, 0.142, 0.184, 0.398, 0.414, 0.415, 0.355, 0.152, 0.144, 0.245, 0.137])
n_5_eff = vD_5/(0.18/9.62)/0.37

print('mean: ', np.mean(n_5_eff), ', SEM: ', sp.stats.sem(n_5_eff))
# Out:
# mean:  37.13253968253969 , SEM:  2.503295034674547
